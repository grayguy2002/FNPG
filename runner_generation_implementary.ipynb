# %%
# 挂载 Google Drive
from google.colab import drive
drive.mount('/content/drive')

# 切换到工作目录
import os
os.chdir('/content/drive/My Drive')

# 安装依赖
# !pip install PyWavelets
# Out:
# Mounted at /content/drive
# ...

# %%
# 运行 FNPG 推理和所有分析
# 脚本会自动执行以下分析:
# - R1-10: 相关性矩阵分析: 计算输入特征（GR, RHOB, NPHI, DTC）与输出特征（CALI, RSHA, RMED, RDEP, SP）之间的 Pearson/Spearman 相关性
# - R1-11: 训练/测试样本统计
# - R2-1:  计算效率指标
# - R1-9:  特征重要性分析
# - R2-3:  逆变换工作流程
# - R2-4:  统计显著性测试

# !python /content/drive/MyDrive/logcompletion/code/fnpg_generation.py
# Out:
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_15.9-15.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_15.9-17.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.1-2.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.1-6 A.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.10-1.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.10-2.pt
# ...

# %%
# !pip install -q torch_geometric
# !pip install -q pyg_lib torch_scatter torch_sparse torch_cluster torch_spline_conv -f https://data.pyg.org/whl/torch-2.4.0+cu121.html
# !pip install -q scikit-image scipy
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 5.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 40.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 50.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 7.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 989.6/989.6 kB 59.9 MB/s eta 0:00:00

# %%
# !python /content/drive/MyDrive/logcompletion/code/flexlognet_reconstruction_inferencing.py
# Out:
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'pyg-lib'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/libpyg.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-scatter'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_scatter/_version_cuda.so
#   import torch_geometric.typing
# /usr/local/lib/python3.12/dist-packages/torch_geometric/__init__.py:4: UserWarning: An issue occurred while importing 'torch-cluster'. Disabling its usage. Stacktrace: Could not load this library: /usr/local/lib/python3.12/dist-packages/torch_cluster/_version_cuda.so
#   import torch_geometric.typing
# ...

# %%
# !python /content/drive/MyDrive/logcompletion/code/baseline_inference_for_r2_4.py
# Out:
# 使用设备: cuda
# ...
# Baseline模型推理 - 用于R2-4统计显著性检验
# ...
#
# 加载测试数据...
#   找到 91 个输入文件
#   找到 91 个目标文件(GCRR)
#   找到 91 个目标文件(GRSB)
#   加载完成！总共 91 口井
#   井0形状: torch.Size([34, 4, 512])
#   井1形状: torch.Size([33, 4, 512])
#
# ...
# 1. 加载ResNet模型
# ...
# 加载权重: /content/drive/MyDrive/logcompletion/model/ctra_exp_GCRR_GRSB/GCRR_GRSB200数据增强_ResNet.pt
# ResNet模型加载成功！
#
# ...
# 运行 ResNet 模型推理
# ...
#
# 处理井 0...
#   样本数: 34
#   批次数: 17
#   每批样本数: 2
#   预测形状: torch.Size([34, 4, 512])
#   目标形状: torch.Size([34, 4, 512])
#   井 0 样本级MSE: 均值=0.960160, 标准差=0.024256
#
# 处理井 1...
#   样本数: 33
#   批次数: 16
#   每批样本数: 2
#   预测形状: torch.Size([32, 4, 512])
#   目标形状: torch.Size([32, 4, 512])
#   井 1 样本级MSE: 均值=0.900305, 标准差=0.087839
#
# ResNet 总样本数: 66
# ResNet 总体MSE: 均值=0.931139, 标准差=0.070277
#
# ...
# 2. 加载Bi-LSTM模型
# ...
# 加载权重: /content/drive/MyDrive/logcompletion/model/ctra_exp_GCRR_GRSB/GCRR_GRSB200数据增强_LSTM.pt
# Bi-LSTM模型加载成功！
#
# ...
# 运行 Bi-LSTM 模型推理
# ...
#
# 处理井 0...
#   样本数: 34
#   批次数: 17
#   每批样本数: 2
#   预测形状: torch.Size([34, 4, 512])
# ...

# %%
# !pip install fastdtw scikit-image
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 5.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for fastdtw: filename=fastdtw-0.3.4-cp312-cp312-linux_x86_64.whl size=567855 sha256=f9b4e95c78fbd6bfe7c582c5739c9bc6f3b1a6e797eb138d19bc65c81545beb6
#   Stored in directory: /root/.cache/pip/wheels/ab/d0/26/b82cb0f49ae73e5e6bba4e8462fff2c9851d7bd2ec64f8891e
# Successfully built fastdtw
# ...

# %%
# !python /content/drive/MyDrive/logcompletion/code/fnpg_generation_with_morphology.py
# Out:
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_15.9-15.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_15.9-17.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.1-2.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.1-6 A.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.10-1.pt
# Loading tensor from file: /content/drive/MyDrive/logcompletion/data/Teamdata/complete_data_for_PIModel/train/Train_x_all_complete_16.10-2.pt
# ...
